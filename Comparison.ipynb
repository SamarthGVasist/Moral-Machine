# %% [markdown]
# # MINI PROJECT

# %%
import pandas as pd
import numpy as np

# %%
data_og = pd.read_csv('SharedResponsesSurvey.csv')
data_cc = pd.read_csv('mproject(2).csv')
# Out:
# /home/taran/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (0,1,8,9,10,11,12,17,20,22,23,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_og = data_og[['ScenarioOrder','ScenarioTypeStrict', 'Saved','Review_age', 'Review_gender','UserCountry3']]
data_og = data_og.dropna()
data_og
# Out:
#         ScenarioOrder ScenarioTypeStrict  Saved  Review_age Review_gender  \
# 0                13.0             Gender    1.0        32.0          male
# 1                 8.0            Fitness    0.0        32.0          male
# 2                 2.0                Age    0.0        32.0          male
# 3                 1.0            Species    0.0        32.0          male
# 4                 5.0            Fitness    0.0        32.0          male
# ...               ...                ...    ...         ...           ...
# 149994           11.0             Gender    0.0        39.0          male
# 149995            2.0             Random    0.0        39.0          male
# 149996            1.0            Species    1.0        32.0          male
# 149997           12.0             Gender    0.0        32.0          male
# 149998            5.0                Age    0.0        32.0          male
#
#        UserCountry3
# 0               RUS
# 1               RUS
# ...

# %% [markdown]
# ### Selecting the age and gender scenarios

# %%
#select only india
data_og_india = data_og[(data_og['UserCountry3'] == "IND")]
data_og_india_age = data_og_india[(data_og_india['ScenarioTypeStrict'] == "Age")]
data_og_india_gender= data_og_india[(data_og_india['ScenarioTypeStrict'] == "Gender")]

# %% [markdown]
# ### Cleaning data

# %%
data_cc = data_cc.replace(to_replace = 1, value = 0)
data_cc = data_cc.replace(to_replace = 2, value = 1)
data_cc
# Out:
#      id          location                citystate       age gender  scene1  \
# 0    55       Vijayanagar     Bangalore, Karnataka  under_25      m       0
# 1    59   Padmanabhanagar     Bangalore, Karnataka  under_25      m       0
# 2    60         Jayanagar     Bangalore, Karnataka  under_25      f       1
# 3    61         Bangalore                Karnataka  under_25      m       1
# 4    62   Vidyaranyapura                 Bengaluru  under_25      m       1
# 5    64   Padmanabhanagar     Bangalore, Karnataka  under_25      m       0
# 6    65     Seetha circle     Bangalore, Karnataka  under_25      m       1
# 7    66         Girinagar     Bangalore, karnataka   over_25      f       1
# 8    67         Banglore                Karnataka   under_25      m       1
# 9    68         Bengaluru  Bengaluru and Karnataka  under_25      m       1
# 10   69         Girinagar    Bangalore , Karnataka  under_25      f       1
# ...

# %%
#Gender Irrespective - age wise
data_cc_age = data_cc[["scene2"]]

# %%
data_cc_age
# Out:
#     scene2
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1
# 5        0
# 6        1
# 7        1
# 8        1
# 9        1
# 10       0
# 11       0
# 12       1
# 13       1
# 14       1
# 15       0
# 16       1
# 17       1
# 18       1
# 19       1
# 20       1
# 21       1
# 22       0
# 23       1
# 24       1
# 25       1
# 26       1
# 27       1
# 28       0
# 29       1
# 30       1
# 31       1
# 32       0
# 33       0
# 34       1
# 35       1
# 36       1
# 37       1
# 38       1
# 39       1
# 40       0
# 41       1
# 42       1
# 43       0
# 44       1
# 45       1

# %% [markdown]
# # Checking difference of choices in the age scenario

# %%
data_cc_age_old =  data_cc[(data_cc['scene2'] == 0)]
data_cc_age_young =  data_cc[(data_cc['scene2'] == 1)]

# %% [markdown]
# ### Distribution from gathered data
# -> older people ~ 26%
#
# -> younger people ~ 74%

# %%
x=(len(data_cc_age_old)/len(data_cc))*100
y=(len(data_cc_age_young)/len(data_cc))*100
print("proportion choosing to save older people:",x)
print("proportion choosing to save younger people:",y)
# Out:
# proportion choosing to save older people: 26.08695652173913
# proportion choosing to save younger people: 73.91304347826086

# %%
#plotting
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['old', 'young']
students = [x,y]
ax.bar(langs,students)
plt.show()

# %% [markdown]
# ### Distribution from MIT data
# -> older people ~ 47%
#
# -> younger people ~ 53%

# %%
#data_og_india_age = data_og_india[(data_og_india['ScenarioTypeStrict'] == "Age")]
data_og_age_young =  data_og_india_age[(data_og_india_age['Saved'] == 0.0)]
data_og_age_old =  data_og_india_age[(data_og_india_age['Saved'] == 1.0)]
x=(len(data_og_age_old)/len(data_og_india_age))*100
y=(len(data_og_age_young)/len(data_og_india_age))*100
print("proportion choosing to save older people:",x)
print("proportion choosing to save younger people:",y)
# Out:
# proportion choosing to save older people: 47.05882352941176
# proportion choosing to save younger people: 52.94117647058824

# %%
#plotting
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['old', 'young']
students = [x,y]
ax.bar(langs,students)
plt.show()

# %% [markdown]
# ### Thus we have difference in age choices.
# From the collected data, we see that the distribution favours selection of young.
# From the gathered data, we see that the distribution is more balanced.

# %% [markdown]
# # Checking difference of choices in the gender scenario

# %% [markdown]
# ### Distribution from gathered data
# -> females ~ 80.5%
#
# -> males ~ 19.5%

# %%
#Gender choices
data_cc_gender_females =  data_cc[(data_cc['scene5'] == 0)]
data_cc_gender_males = data_cc[(data_cc['scene5'] == 1)]
x=(len(data_cc_gender_females)/len(data_cc))*100
y=(len(data_cc_gender_males)/len(data_cc))*100
print("proportion choosing to save females:",x)
print("proportion choosing to save males:",y)
# Out:
# proportion choosing to save females: 80.43478260869566
# proportion choosing to save males: 19.565217391304348

# %%
#plotting
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['females', 'males']
students = [x,y]
ax.bar(langs,students)
plt.show()

# %% [markdown]
# ### Distribution from MIT data
# -> females ~ 49%
#
# -> males ~ 51%

# %%
#data_og_india_age = data_og_india[(data_og_india['ScenarioTypeStrict'] == "Age")]
data_og_male =  data_og_india_gender[(data_og_india_gender['Saved'] == 0.0)]
data_og_female =  data_og_india_gender[(data_og_india_gender['Saved'] == 1.0)]
x=(len(data_og_female)/len(data_og_india_age))*100
y=(len(data_og_male)/len(data_og_india_age))*100
print("proportion choosing to save females:",x)
print("proportion choosing to save males:",y)
# Out:
# proportion choosing to save females: 48.03921568627451
# proportion choosing to save males: 50.98039215686274

# %%
#plotting
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['females', 'males']
students = [x,y]
ax.bar(langs,students)
plt.show()

# %% [markdown]
# ### Thus we have difference in age choices.
# From the collected data, we see that the distribution favours selection of young.
# From the gathered data, we see that the distribution is more balanced.

# %% [markdown]
# ## From both scenarios, we can see that there exists a difference in locally gathered data(focused target group) vs general data collection(idk how to word this). Hence, we can conclude there is case for collection of data locally for targeting higher accuracy.
